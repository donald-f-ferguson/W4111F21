# %% [markdown]
# # COMS W4111: Introduction to Databases
#
# ## Homework 0 - Environment Setup

# %% [markdown]
# ### Introduction/Overview
#
# Please consult the HW0: Environment PDF for detailed instructions. Complete all the tests in this notebook and submit only this notebook as a PDF to GradeScope. To convert the jupyter notebook into a pdf you can use either of the following methods:
#
# - File --> Print Preview --> Print --> Save to PDF
#
# - File --> Download As HTML --> Print --> Save to PDF
#
#
# __Due date: September 17, 10:00am ET on GradeScope__
#
# Please note: You may NOT use late days for the submission of this assignment. Check Courseworks for GradeScope access.
#
#
# It is recommended that you put the screenshots into the same folder as this notebook so you do not have to alter the path to include your images.
#
# Please read all the instructions thoroughly!

# %%
# Print your name, uni, and track below

name = "YOUR NAME HERE"
uni = "YOUR UNI HERE"
track = "Programming/Non-Programming"

print(name)
print(uni)
print(track)
# Out:
# YOUR NAME HERE
# YOUR UNI HERE
# Programming/Non-Programming

# %% [markdown]
# ## Anaconda
#
# Run the following cells to ensure that you have the correct version of Python and all necessary packages installed.
#
# #### Python Version

# %%
import sys

print("Python version information:", sys.version_info, "\n")
if sys.version_info.major != 3 or \
    ((sys.version_info.major == 3) and (sys.version_info.minor < 5)):
    print("You have an invalid version of Python.")
else:
    print("Your Python version is OK.")
# Out:
# Python version information: sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
#
# Your Python version is OK.

# %% [markdown]
# #### Python Path

# %%
python_found = False
anaconda_found = False

for p in sys.path:
    print(p)
    if "anaconda3" in p:
        print("Found anaconda3")
        anaconda_found = True
    if "python" in p:
        print("Found some kind of Python.")
        if not anaconda_found:
            print("Found some type of Python other than Anaconda.")
            print("Test fails")
        else:
            print("OK. Path is good.")
            python_found = True
        break
    
if python_found and anaconda_found:
    print("\nPassed all path tests.")
else:
    print("\nFailed path tests.")
# Out:
# /Users/carriehaykellar/Downloads/W4111_HW0
# /Users/carriehaykellar/opt/anaconda3/lib/python38.zip
# Found anaconda3
# Found some kind of Python.
# OK. Path is good.
#
# Passed all path tests.

# %% [markdown]
# #### Test Conda/Anaconda Version

# %%
import conda

# %%
conda_version_info =  conda.sys.version_info
print("Your conda version info is\n", conda_version_info)

print("Conda version information:", conda_version_info, "\n")
if conda_version_info.major != 3 or \
    ((conda_version_info.major == 3) and (conda_version_info.minor < 6)):
    print("You have an invalid version of Conda.")
else:
    print("Your Conda version is OK.")
# Out:
# Your conda version info is
#  sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
# Conda version information: sys.version_info(major=3, minor=8, micro=5, releaselevel='final', serial=0)
#
# Your Conda version is OK.

# %% [markdown]
# #### Test Pandas

# %%
import pandas
p_version = pandas.__version__
p_nums = p_version.split(".")

print("Your pandas version is ", p_version)
if p_nums[0] != '1':
    print("Your version is invalid.")
else:
    print("Your version is OK.")
    
# This checks to see if you are on pandas 1.0.5 or 1.2.0 both of which are OK
# Out:
# Your pandas version is  1.2.0
# Your version is OK.

# %% [markdown]
# If you do not have Pandas already you will need to install Pandas using the following cell:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\arape\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\arape\anaconda3\lib\site-packages (from pandas) (2020.5)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\arape\anaconda3\lib\site-packages (from pandas) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\arape\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\arape\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# #### Install ipython-sql

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\arape\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlparse in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: six in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\arape\anaconda3\lib\site-packages (from ipython-sql) (1.3.21)
# Requirement already satisfied: setuptools>=18.5 in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (51.0.0.post20201207)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.17.2)
# Requirement already satisfied: backcall in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: decorator in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: colorama in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments in c:\users\arape\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.7.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\arape\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\arape\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %% [markdown]
# - If you got errors, please follow the [instructions in the ipython-sql site](https://github.com/catherinedevlin/ipython-sql) to install the magic.
#
#
# - __NOTE:__ Running the cell above may produce multiple notifications about installing requirements or requirement already satisfied. That is normal.
#
#
#
# - Once you get the install to work without errors, run the following cell.

# %%
# %load_ext sql

# %% [markdown]
# - If you did not get an error response, your test passed.
#
#
# - If you run the cell twice, your answer should be:
#
# ```
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ```

# %% [markdown]
# #### SQLAlchemy/PyMySQL

# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\arape\anaconda3\lib\site-packages (1.3.21)
# Requirement already satisfied: pymysql in c:\users\arape\anaconda3\lib\site-packages (0.10.1)

# %% [markdown]
# ## PyCharm
#
# Required for Programming Track only, but recommended for all. Follow the instructions to setup PyCharm and run the test. Take a screenshot and insert it into the notebook using the cell below. You may have to change the path to the name and/or location of your image.

# %%
from IPython.display import Image 

Image("./PyCharmScreenshot.png")

# %% [markdown]
# ## DataGrip
# Follow the instructions to setup DataGrip and connect DataGrip to your AWS server. Insert your screenshot of the successful query on the Lahman database into the notebook using the cell below. You may have to change the path to the name and/or location of your image.

# %%
Image("./DataGripScreenshot.png")

# %% [markdown]
# The code below indicates how to connect this notebook to your AWS Database.
#
# You will need to change the username, password, and endpoint to match

# %%
# %load_ext sql
# %sql mysql+pymysql://username:password@endpointurl/lahmansbaseballdb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Run the cell below to query the AWS database from the notebook:

# %%
# %sql SELECT * FROM lahmansbaseballdb.People LIMIT 10;
# Out:
#  * mysql+pymysql://admin:***@ara-project.ckkqqktwkcji.us-east-1.rds.amazonaws.com/lahman2017raw
# 100 rows affected.
# [('aardsda01', '1981', '12', '27', 'USA', 'CO', 'Denver', '', '', '', '', '', '', 'David', 'Aardsma', 'David Allan', '215', '75', 'R', 'R', '2004-04-06', '2015-08-23', 'aardd001', 'aardsda01'),
#  ('aaronha01', '1934', '2', '5', 'USA', 'AL', 'Mobile', '', '', '', '', '', '', 'Hank', 'Aaron', 'Henry Louis', '180', '72', 'R', 'R', '1954-04-13', '1976-10-03', 'aaroh101', 'aaronha01'),
#  ('aaronto01', '1939', '8', '5', 'USA', 'AL', 'Mobile', '1984', '8', '16', 'USA', 'GA', 'Atlanta', 'Tommie', 'Aaron', 'Tommie Lee', '190', '75', 'R', 'R', '1962-04-10', '1971-09-26', 'aarot101', 'aaronto01'),
#  ('aasedo01', '1954', '9', '8', 'USA', 'CA', 'Orange', '', '', '', '', '', '', 'Don', 'Aase', 'Donald William', '190', '75', 'R', 'R', '1977-07-26', '1990-10-03', 'aased001', 'aasedo01'),
#  ('abadan01', '1972', '8', '25', 'USA', 'FL', 'Palm Beach', '', '', '', '', '', '', 'Andy', 'Abad', 'Fausto Andres', '184', '73', 'L', 'L', '2001-09-10', '2006-04-13', 'abada001', 'abadan01'),
#  ('abadfe01', '1985', '12', '17', 'D.R.', 'La Romana', 'La Romana', '', '', '', '', '', '', 'Fernando', 'Abad', 'Fernando Antonio', '220', '73', 'L', 'L', '2010-07-28', '2017-10-01', 'abadf001', 'abadfe01'),
#  ('abadijo01', '1850', '11', '4', 'USA', 'PA', 'Philadelphia', '1905', '5', '17', 'USA', 'NJ', 'Pemberton', 'John', 'Abadie', 'John W.', '192', '72', 'R', 'R', '1875-04-26', '1875-06-10', 'abadj101', 'abadijo01'),
#  ('abbated01', '1877', '4', '15', 'USA', 'PA', 'Latrobe', '1957', '1', '6', 'USA', 'FL', 'Fort Lauderdale', 'Ed', 'Abbaticchio', 'Edward James', '170', '71', 'R', 'R', '1897-09-04', '1910-09-15', 'abbae101', 'abbated01'),
#  ('abbeybe01', '1869', '11', '11', 'USA', 'VT', 'Essex', '1962', '6', '11', 'USA', 'VT', 'Colchester', 'Bert', 'Abbey', 'Bert Wood', '175', '71', 'R', 'R', '1892-06-14', '1896-09-23', 'abbeb101', 'abbeybe01'),
#  ('abbeych01', '1866', '10', '14', 'USA', 'NE', 'Falls City', '1926', '4', '27', 'USA', 'CA', 'San Francisco', 'Charlie', 'Abbey', 'Charles S.', '169', '68', 'L', 'L', '1893-08-16', '1897-08-19', 'abbec101', 'abbeych01'),
#  ('abbotda01', '1862', '3', '16', 'USA', 'OH', 'Portage', '1930', '2', '13', 'USA', 'MI', 'Ottawa Lake', 'Dan', 'Abbott', 'Leander Franklin', '190', '71', 'R', 'R', '1890-04-19', '1890-05-23', 'abbod101', 'abbotda01'),
#  ('abbotfr01', '1874', '10', '22', 'USA', 'OH', 'Versailles', '1935', '6', '11', 'USA', 'CA', 'Los Angeles', 'Fred', 'Abbott', 'Harry Frederick', '180', '70', 'R', 'R', '1903-04-25', '1905-09-20', 'abbof101', 'abbotfr01'),
#  ('abbotgl01', '1951', '2', '16', 'USA', 'AR', 'Little Rock', '', '', '', '', '', '', 'Glenn', 'Abbott', 'William Glenn', '200', '78', 'R', 'R', '1973-07-29', '1984-08-08', 'abbog001', 'abbotgl01'),
#  ('abbotje01', '1972', '8', '17', 'USA', 'GA', 'Atlanta', '', '', '', '', '', '', 'Jeff', 'Abbott', 'Jeffrey William', '190', '74', 'R', 'L', '1997-06-10', '2001-09-29', 'abboj002', 'abbotje01'),
#  ('abbotji01', '1967', '9', '19', 'USA', 'MI', 'Flint', '', '', '', '', '', '', 'Jim', 'Abbott', 'James Anthony', '200', '75', 'L', 'L', '1989-04-08', '1999-07-21', 'abboj001', 'abbotji01'),
#  ('aberscl01', '1921', '8', '28', 'USA', 'IL', 'Chicago', '1973', '6', '23', 'USA', 'CA', 'Vallejo', 'Cliff', 'Aberson', 'Clifford Alexander', '200', '72', 'R', 'R', '1947-07-18', '1949-05-09', 'aberc101', 'aberscl01'),
#  ('ablesha01', '1883', '10', '4', 'USA', 'TX', 'Terrell', '1951', '2', '8', 'USA', 'TX', 'San Antonio', 'Harry', 'Ables', 'Harry Terrell', '200', '74', 'R', 'L', '1905-09-04', '1911-05-05', 'ableh101', 'ablesha01'),
#  ('abnersh01', '1966', '6', '17', 'USA', 'OH', 'Hamilton', '', '', '', '', '', '', 'Shawn', 'Abner', 'Shawn Wesley', '190', '73', 'R', 'R', '1987-09-08', '1992-10-03', 'abnes001', 'abnersh01'),
#  ('abramca01', '1924', '3', '2', 'USA', 'PA', 'Philadelphia', '1997', '2', '25', 'USA', 'FL', 'Fort Lauderdale', 'Cal', 'Abrams', 'Calvin Ross', '185', '72', 'L', 'L', '1949-04-19', '1956-05-09', 'abrac101', 'abramca01'),
#  ('abramge01', '1899', '11', '9', 'USA', 'WA', 'Seattle', '1986', '12', '5', 'USA', 'FL', 'Clearwater', 'George', 'Abrams', 'George Allen', '170', '69', 'R', 'R', '1923-04-19', '1923-05-04', 'abrag101', 'abramge01'),
#  ('abregjo01', '1962', '7', '4', 'USA', 'TX', 'Corpus Christi', '', '', '', '', '', '', 'Johnny', 'Abrego', 'Johnny Ray', '185', '72', 'R', 'R', '1985-09-04', '1985-10-03', 'abrej001', 'abregjo01'),
#  ('abreubo01', '1974', '3', '11', 'Venezuela', 'Aragua', 'Maracay', '', '', '', '', '', '', 'Bobby', 'Abreu', 'Bob Kelly', '220', '72', 'L', 'R', '1996-09-01', '2014-09-28', 'abreb001', 'abreubo01'),
#  ('abreujo01', '1913', '5', '24', 'USA', 'CA', 'Oakland', '1993', '3', '17', 'USA', 'CA', 'Hayward', 'Joe', 'Abreu', 'Joseph Lawrence', '160', '68', 'R', 'R', '1942-04-23', '1942-07-11', 'abrej101', 'abreujo01'),
#  ('abreujo02', '1987', '1', '29', 'Cuba', 'Cienfuegos', 'Cienfuegos', '', '', '', '', '', '', 'Jose', 'Abreu', 'Jose Dariel', '255', '75', 'R', 'R', '2014-03-31', '2017-10-01', 'abrej003', 'abreujo02'),
#  ('abreuju01', '1985', '4', '8', 'D.R.', 'Duarte', 'San Francisco de Macoris', '', '', '', '', '', '', 'Juan', 'Abreu', 'Juan de Dios', '185', '72', 'R', 'R', '2011-08-29', '2011-09-27', 'abrej002', 'abreuju01'),
#  ('abreuto01', '1984', '11', '13', 'D.R.', 'Puerto Plata', 'Puerto Plata', '', '', '', '', '', '', 'Tony', 'Abreu', 'Etanislao Toni', '200', '70', 'B', 'R', '2007-05-22', '2014-07-28', 'abret001', 'abreuto01'),
#  ('abreuwi01', '1977', '4', '5', 'D.R.', 'Sanchez Ramirez', 'Cotui', '', '', '', '', '', '', 'Winston', 'Abreu', 'Winston Leonardo', '170', '74', 'R', 'R', '2006-08-06', '2009-07-25', 'abrew001', 'abreuwi01'),
#  ('acostma01', '1981', '5', '1', 'Panama', 'Colon', 'Colon', '', '', '', '', '', '', 'Manny', 'Acosta', 'Manuel Alcides', '215', '76', 'R', 'R', '2007-08-12', '2012-10-03', 'acosm001', 'acostma01'),
#  ('acostme01', '1896', '5', '19', 'Cuba', '', 'Bauta', '1963', '11', '17', 'USA', 'FL', 'Miami', 'Merito', 'Acosta', 'Baldomero Pedro', '140', '67', 'L', 'L', '1913-06-15', '1918-09-02', 'acosm101', 'acostme01'),
#  ('acrema01', '1968', '9', '16', 'USA', 'CA', 'Concord', '', '', '', '', '', '', 'Mark', 'Acre', 'Mark Robert', '235', '80', 'R', 'R', '1994-05-13', '1997-05-10', 'acrem001', 'acrema01'),
#  ('actama99', '1969', '1', '11', 'D.R.', 'San Pedro de Macoris', 'San Pedro de Macoris', '', '', '', '', '', '', 'Manny', 'Acta', 'Manuel Elias', '172', '74', 'R', 'R', '', '', 'actam801', 'actama99'),
#  ('adairbi99', '1913', '2', '10', 'USA', 'AL', 'Mobile', '2002', '6', '17', 'USA', 'AL', 'Bay Minette', 'Bill', 'Adair', 'Marion Danne', '168', '72', 'R', 'R', '', '', 'adaib801', 'adairbi99'),
#  ('adairje01', '1936', '12', '17', 'USA', 'OK', 'Sand Springs', '1987', '5', '31', 'USA', 'OK', 'Tulsa', 'Jerry', 'Adair', 'Kenneth Jerry', '175', '72', 'R', 'R', '1958-09-02', '1970-05-03', 'adaij101', 'adairje01'),
#  ('adairji01', '1907', '1', '25', 'USA', 'TX', 'Waxahachie', '1982', '12', '9', 'USA', 'TX', 'Farmers Branch', 'Jimmy', 'Adair', 'James Aubrey', '154', '70', 'R', 'R', '1931-08-24', '1931-09-07', 'adaij102', 'adairji01'),
#  ('adamecr01', '1991', '7', '26', 'D.R.', 'Distrito Nacional', 'Santo Domingo', '', '', '', '', '', '', 'Cristhian', 'Adames', 'Cristhian Pascual', '185', '72', 'B', 'R', '2014-07-29', '2017-04-28', 'adamc001', 'adamecr01'),
#  ('adamsac01', '1910', '3', '2', 'USA', 'CA', 'Willows', '2006', '2', '26', 'USA', 'GA', 'Albany', 'Ace', 'Adams', 'Ace Townsend', '182', '70', 'R', 'R', '1941-04-15', '1946-04-24', 'adama101', 'adamsac01'),
#  ('adamsau01', '1986', '8', '19', 'USA', 'AL', 'Montgomery', '', '', '', '', '', '', 'Austin', 'Adams', 'Austin David', '200', '71', 'R', 'R', '2014-07-12', '2016-09-27', 'adama001', 'adamsau01'),
#  ('adamsau02', '1991', '5', '5', 'USA', 'FL', 'Tampa', '', '', '', '', '', '', 'Austin', 'Adams', 'Austin Lance', '225', '74', 'R', 'R', '2017-07-15', '2017-10-01', 'adama002', 'adamsau02'),
#  ('adamsba01', '1882', '5', '18', 'USA', 'IN', 'Tipton', '1968', '7', '27', 'USA', 'MD', 'Silver Spring', 'Babe', 'Adams', 'Charles Benjamin', '185', '71', 'L', 'R', '1906-04-18', '1926-08-11', 'adamb104', 'adamsba01'),
#  ('adamsbe01', '1891', '6', '21', 'USA', 'TX', 'Wharton', '1940', '6', '24', 'USA', 'CA', 'Los Angeles', 'Bert', 'Adams', 'John Bertram', '185', '73', 'B', 'R', '1910-08-30', '1919-09-28', 'adamb106', 'adamsbe01'),
#  ('adamsbo01', '1901', '7', '24', 'USA', 'MA', 'Holyoke', '1996', '10', '17', 'USA', 'PA', 'Lemoyne', 'Bob', 'Adams', 'Robert Burnette', '168', '71', 'R', 'R', '1925-09-22', '1925-09-23', 'adamb107', 'adamsbo01'),
#  ('adamsbo02', '1907', '1', '20', 'USA', 'AL', 'Birmingham', '1970', '3', '6', 'USA', 'FL', 'Jacksonville', 'Bob', 'Adams', 'Robert Andrew', '165', '72', 'R', 'R', '1931-09-27', '1932-09-17', 'adamb102', 'adamsbo02'),
#  ('adamsbo03', '1921', '12', '14', 'USA', 'CA', 'Tuolumne', '1997', '2', '13', 'USA', 'WA', 'Gig Harbor', 'Bobby', 'Adams', 'Robert Henry', '160', '70', 'R', 'R', '1946-04-16', '1959-04-22', 'adamb103', 'adamsbo03'),
#  ('adamsbo04', '1952', '1', '6', 'USA', 'PA', 'Pittsburgh', '', '', '', '', '', '', 'Bob', 'Adams', 'Robert Melvin', '200', '74', 'R', 'R', '1977-07-10', '1977-09-29', 'adamb105', 'adamsbo04'),
#  ('adamsbu01', '1915', '6', '24', 'USA', 'CO', 'Trinidad', '1990', '9', '1', 'USA', 'CA', 'Rancho Mirage', 'Buster', 'Adams', 'Elvin Clark', '180', '72', 'R', 'R', '1939-04-27', '1947-09-21', 'adamb101', 'adamsbu01'),
#  ('adamsda01', '1887', '6', '19', 'USA', 'MO', 'St. Louis', '1964', '10', '6', 'USA', 'MO', 'St. Louis', 'Dan', 'Adams', 'Daniel Leslie', '165', '71', 'R', 'R', '1914-05-22', '1915-09-26', 'adamd103', 'adamsda01'),
#  ('adamsda02', '1987', '5', '15', 'USA', 'FL', 'Margate', '', '', '', '', '', '', 'David', 'Adams', 'David Lee', '205', '74', 'R', 'R', '2013-05-15', '2013-09-29', 'adamd001', 'adamsda02'),
#  ('adamsdi01', '1920', '4', '8', 'USA', 'CA', 'Tuolumne', '2016', '9', '14', 'USA', 'CA', 'Fallbrook', 'Dick', 'Adams', 'Richard Leroy', '185', '72', 'R', 'L', '1947-05-20', '1947-09-28', 'adamd102', 'adamsdi01'),
#  ('adamsdo01', '1943', '1', '27', 'USA', 'WI', 'Blue River', '', '', '', '', '', '', 'Doug', 'Adams', 'Harold Douglas', '185', '75', 'L', 'R', '1969-09-08', '1969-10-01', 'adamd101', 'adamsdo01'),
#  ('adamsge01', '1855', '1', '26', 'USA', 'MA', 'Worcester', '1920', '10', '11', 'USA', 'WA', 'Clarkston', 'George', 'Adams', 'George Henry', '175', '66', 'R', 'R', '1879-06-14', '1879-06-21', 'adamg102', 'adamsge01'),
#  ('adamsgl01', '1947', '10', '4', 'USA', 'MA', 'Northbridge', '', '', '', '', '', '', 'Glenn', 'Adams', 'Glenn Charles', '180', '73', 'L', 'R', '1975-05-04', '1982-10-03', 'adamg101', 'adamsgl01'),
#  ('adamshe01', '1928', '4', '14', 'USA', 'CA', 'Hollywood', '2012', '2', '1', 'USA', 'OK', 'Tulsa', 'Herb', 'Adams', 'Herbert Loren', '160', '69', 'L', 'L', '1948-09-17', '1950-08-30', 'adamh101', 'adamshe01'),
#  ('adamsji01', '1868', '', '', 'USA', 'IL', 'East St. Louis', '', '', '', '', '', '', 'Jim', 'Adams', 'James J.', '148', '66', '', 'R', '1890-04-21', '1890-04-21', 'adamj101', 'adamsji01'),
#  ('adamsjo01', '1877', '10', '28', 'USA', 'IL', 'Cowden', '1952', '10', '8', 'USA', 'MO', 'Bachelor', 'Joe', 'Adams', 'Joseph Edward', '190', '72', 'R', 'L', '1902-04-26', '1902-04-26', 'adamj102', 'adamsjo01'),
#  ('adamsjo02', '1971', '7', '2', 'USA', 'CA', 'Lakewood', '', '', '', '', '', '', 'Joel', 'Adamson', 'Joel Lee', '185', '76', 'L', 'L', '1996-04-10', '1998-04-26', 'adamj001', 'adamsjo02'),
#  ('adamska01', '1891', '8', '11', 'USA', 'GA', 'Columbus', '1967', '9', '17', 'USA', 'WA', 'Everett', 'Karl', 'Adams', 'Karl Tutwiler', '170', '74', 'R', 'R', '1914-04-19', '1915-09-23', 'adamk101', 'adamska01'),
#  ('adamsla01', '1989', '11', '13', 'USA', 'OK', 'Talihina', '', '', '', '', '', '', 'Lane', 'Adams', 'Lane Weston', '220', '75', 'R', 'R', '2014-09-01', '2017-10-01', 'adaml001', 'adamsla01'),
#  ('adamsma01', '1988', '8', '31', 'USA', 'PA', 'Philipsburg', '', '', '', '', '', '', 'Matt', 'Adams', 'Matthew James', '260', '75', 'L', 'R', '2012-05-20', '2017-09-30', 'adamm002', 'adamsma01'),
#  ('adamsmi01', '1947', '9', '13', 'USA', 'CA', 'San Diego', '', '', '', '', '', '', 'Mike', 'Adamson', 'John Michael', '185', '74', 'R', 'R', '1967-07-01', '1969-05-07', 'adamm101', 'adamsmi01'),
#  ('adamsmi02', '1948', '7', '24', 'USA', 'OH', 'Cincinnati', '', '', '', '', '', '', 'Mike', 'Adams', 'Robert Michael', '180', '69', 'R', 'R', '1972-09-10', '1978-07-25', 'adamm102', 'adamsmi02'),
#  ('adamsmi03', '1978', '7', '29', 'USA', 'TX', 'Corpus Christi', '', '', '', '', '', '', 'Mike', 'Adams', 'Jon Michael', '210', '77', 'R', 'R', '2004-05-18', '2014-09-18', 'adamm001', 'adamsmi03'),
#  ('adamsre01', '1921', '10', '7', 'USA', 'CA', 'Parlier', '2017', '1', '18', 'USA', 'CA', 'Fresno', 'Red', 'Adams', 'Charles Dwight', '185', '72', 'R', 'R', '1946-05-05', '1946-07-02', 'adamr101', 'adamsre01'),
#  ('adamsri01', '1878', '12', '24', 'USA', 'TX', 'Paris', '1955', '3', '10', 'USA', 'TX', 'Paris', 'Rick', 'Adams', 'Reuben Alexander', '165', '72', 'L', 'L', '1905-07-13', '1905-09-29', 'adamr102', 'adamsri01'),
#  ('adamsri02', '1959', '1', '21', 'USA', 'CA', 'Upland', '2011', '10', '28', 'USA', 'CA', 'Rancho Cucamonga', 'Ricky', 'Adams', 'Ricky Lee', '180', '74', 'R', 'R', '1982-09-15', '1985-10-05', 'adamr001', 'adamsri02'),
#  ('adamsru01', '1980', '8', '30', 'USA', 'NC', 'Laurinburg', '', '', '', '', '', '', 'Russ', 'Adams', 'Russ Moore', '205', '72', 'L', 'R', '2004-09-03', '2009-06-30', 'adamr002', 'adamsru01'),
#  ('adamsry01', '1987', '4', '21', 'USA', 'LA', 'New Orleans', '', '', '', '', '', '', 'Ryan', 'Adams', 'Ryan Scott', '185', '71', 'R', 'R', '2011-05-20', '2011-09-19', 'adamr003', 'adamsry01'),
#  ('adamssp01', '1894', '8', '26', 'USA', 'PA', 'Zerbe', '1989', '2', '24', 'USA', 'PA', 'Pottsville', 'Sparky', 'Adams', 'Earl John', '151', '65', 'R', 'R', '1922-09-18', '1934-09-30', 'adams101', 'adamssp01'),
#  ('adamssp02', '1898', '6', '21', 'USA', 'UT', 'Layton', '1970', '11', '24', 'USA', 'UT', 'Salt Lake City', 'Spencer', 'Adams', 'Spencer Dewey', '158', '69', 'L', 'R', '1923-04-22', '1927-10-02', 'adams102', 'adamssp02'),
#  ('adamste01', '1973', '3', '6', 'USA', 'AL', 'Mobile', '', '', '', '', '', '', 'Terry', 'Adams', 'Terry Wayne', '180', '75', 'R', 'R', '1995-08-10', '2005-05-23', 'adamt001', 'adamste01'),
#  ('adamswi01', '1890', '9', '27', 'USA', 'PA', 'Clearfield', '1937', '6', '18', 'USA', 'NY', 'Albany', 'Willie', 'Adams', 'James Irvin', '180', '76', 'R', 'R', '1912-06-30', '1919-09-06', 'adamw101', 'adamswi01'),
#  ('adamswi02', '1972', '10', '8', 'USA', 'NM', 'Gallup', '', '', '', '', '', '', 'Willie', 'Adams', 'William Edward', '215', '79', 'R', 'R', '1996-06-11', '1997-08-14', 'adamw001', 'adamswi02'),
#  ('adcocjo01', '1927', '10', '30', 'USA', 'LA', 'Coushatta', '1999', '5', '3', 'USA', 'LA', 'Coushatta', 'Joe', 'Adcock', 'Joseph Wilbur', '210', '76', 'R', 'R', '1950-04-23', '1966-10-01', 'adcoj101', 'adcocjo01'),
#  ('adcocna01', '1988', '2', '25', 'USA', 'KY', 'Elizabethtown', '', '', '', '', '', '', 'Nathan', 'Adcock', 'Nathan Masler', '235', '76', 'R', 'R', '2011-03-31', '2015-07-26', 'adcon001', 'adcocna01'),
#  ('addisbo01', '1925', '11', '6', 'USA', 'OH', 'Mineral', '2016', '11', '15', 'USA', 'OH', 'Mentor', 'Bob', 'Addis', 'Robert Gordon', '175', '72', 'L', 'R', '1950-09-01', '1953-06-12', 'addib101', 'addisbo01'),
#  ('adducji01', '1959', '8', '9', 'USA', 'IL', 'Chicago', '', '', '', '', '', '', 'Jim', 'Adduci', 'James David', '200', '77', 'L', 'L', '1983-09-12', '1989-07-26', 'adduj001', 'adducji01')]

# %% [markdown]
# ## Postman
#
# Required for Programming Track only. Follow the instructions to setup Postman. Insert your screenshot of the successful GET request on the website you chose using the cell below. You may have to change the path to the name and/or location of your image.

# %%
Image("./PostmanScreenshot.png")
